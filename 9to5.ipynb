-- %% [markdown]
-- # <span style="font-size: 20pt; font-family: Montserrat, sans-serif; color: rgb(92, 148, 206); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Graded Assignment 3: 9 to 5</span>
--
--
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to show off your SQL skills! For each question, copy the SQL query you used and make note of the answer.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For this assignment, you will be using the Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results which can be found on</span> [<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(17, 85, 204); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; text-decoration-line: underline; vertical-align: baseline; white-space: pre-wrap;">Kaggle</span>](https://www.kaggle.com/bls/employment)<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Business Issue</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">You are working for the Bureau of Labor Statistics with the United States government and have been approached by your boss with an important meeting request. You have been asked by your supervisor to meet with Dolly Parton whose nonprofit is looking to shed light on the state of employment in the United States. As part of the 9 to 5 project, their research is focused on production and nonsupervisory employees and how those employees fare compared to all employees in the United States. While the data the BLS collects from the CES is publicly available, Dolly Parton and her colleagues need your assistance navigating the thousands of rows in each table in LaborStatisticsDB.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">About the Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">This dataset comes directly from the Bureau of Labor Statistics’ Current Employment Survey (CES). Here are some things you need to know:</span>
--
-- 1. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The industry table contains an NAICS code. This is different from the industry code. NAICS stands for North American Industry Classification System.</span>
--
-- 2. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Series ID is composed of multiple different codes. CES stands for Current Employment Survey, the name of the survey which collected the data. The industry code as specified by the BLS and the data type code as specified in the datatype table.</span>
--
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Set Up</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To connect to the database, use the same connection info used during the SQL lessons.&nbsp;</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For the assignment, we will be using the LaborStatisticsDB database.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Database Exploration</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To start with, let’s get to know the database further.</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: &quot;Times New Roman&quot;; font-size: 10pt; white-space: pre-wrap;">Use this space to make note of each table in the database, the columns within each table, each column’s data type, and how the tables are connected. You can write this down or draw a diagram. Whatever method helps you get an understanding of what is going on with LaborStatisticsDB.</span>

-- %% [markdown]
-- To add a photo, diagram or document to your file, drop the file into the folder that holds this notebook.  Use the the link button to the right of the  \</\> symbol in the gray part of this cell, the link is just the name of your file.

-- %%
-- upload image

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: Arvo, serif; font-size: 10pt; white-space: pre-wrap;">What is the datatype for women employees?</span>

-- %%
-- The datatype of "WOMEN EMPLOYEES" is a string and the code is 10 and an integer. I tried using the DESCRIBE function and it didnt work. 
SELECT *
FROM LaborStatisticsDB.dbo.datatype AS dt
WHERE dt.data_type_text LIKE 'women%'
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.042
-- <table><tr><th>data_type_code</th><th>data_type_text</th></tr><tr><td>10</td><td>WOMEN EMPLOYEES</td></tr><tr><td>39</td><td>WOMEN EMPLOYEES-TO-ALL EMPLOYEES RATIO</td></tr></table>

-- %%
SELECT COUNT(ser.series_title)
FROM LaborStatisticsDB.dbo.series AS ser
WHERE ser.series_title LIKE 'women%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.053
-- <table><tr><th>(No column name)</th></tr><tr><td>1372</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the series id for&nbsp; women employees in the commercial banking industry in the financial activities supersector?</span>

-- %%
-- The series ID is either CE5552211010 or CEU55221101
SELECT s.series_id, i.industry_name, ss.supersector_name, s.series_title
FROM LaborStatisticsDB.dbo.series AS s 
JOIN LaborStatisticsDB.dbo.industry AS i 
ON s.industry_code = i.industry_code
JOIN LaborStatisticsDB.dbo.supersector as ss 
ON s.supersector_code = ss.supersector_code
WHERE s.series_title = 'women employees' AND i.industry_name = 'commercial banking' AND ss.supersector_name = 'financial activities'
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.047
-- <table><tr><th>series_id</th><th>industry_name</th><th>supersector_name</th><th>series_title</th></tr><tr><td>CES5552211010</td><td>Commercial banking</td><td>Financial activities</td><td>Women employees</td></tr><tr><td>CEU5552211010</td><td>Commercial banking</td><td>Financial activities</td><td>Women employees</td></tr></table>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.industry AS i
WHERE i.industry_name = 'commercial banking'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.035
-- <table><tr><th>id</th><th>industry_code</th><th>naics_code</th><th>publishing_status</th><th>industry_name</th><th>display_level</th><th>selectable</th><th>sort_sequence</th></tr><tr><td>563</td><td>55522110</td><td>52211</td><td>A</td><td>Commercial banking</td><td>6</td><td>T</td><td>564</td></tr></table>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.supersector AS ss 
WHERE ss.supersector_name = 'financial activities'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.041
-- <table><tr><th>supersector_code</th><th>supersector_name</th></tr><tr><td>55</td><td>Financial activities</td></tr></table>

-- %%
SELECT TOP 10 *
FROM LaborStatisticsDB.dbo.series AS s
WHERE s.series_title = 'women employees'
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.041
-- <table><tr><th>series_id</th><th>supersector_code</th><th>industry_code</th><th>data_type_code</th><th>seasonal</th><th>series_title</th></tr><tr><td>CES0000000010</td><td>0</td><td>00000000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES0500000010</td><td>5</td><td>05000000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES0600000010</td><td>6</td><td>06000000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES0700000010</td><td>7</td><td>07000000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES0800000010</td><td>8</td><td>08000000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES1000000010</td><td>10</td><td>10000000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES1011330010</td><td>10</td><td>10113300</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES1021000010</td><td>10</td><td>10210000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES1021100010</td><td>10</td><td>10211000</td><td>10</td><td>S</td><td>Women employees</td></tr><tr><td>CES1021200010</td><td>10</td><td>10212000</td><td>10</td><td>S</td><td>Women employees</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Join in on the Fun</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to start joining! You can choose the type of join you use, just make sure to make a&nbsp; note!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join&nbsp; annual_2016 with series on series_id. We only want the data in the annual_2016 table to be included in the result.</span>

-- %%
SELECT TOP 10 *
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.169
-- <table><tr><th>id</th><th>series_id</th><th>year</th><th>period</th><th>value</th><th>footnote_codes</th><th>original_file</th><th>series_id</th><th>supersector_code</th><th>industry_code</th><th>data_type_code</th><th>seasonal</th><th>series_title</th></tr><tr><td>0</td><td>CEU5500000007</td><td>2016</td><td>M13</td><td>36.9</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000007</td><td>55</td><td>55000000</td><td>7</td><td>U</td><td>Average weekly hours of production and nonsupervisory employees</td></tr><tr><td>1</td><td>CEU5500000008</td><td>2016</td><td>M13</td><td>26.11</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000008</td><td>55</td><td>55000000</td><td>8</td><td>U</td><td>Average hourly earnings of production and nonsupervisory employees</td></tr><tr><td>2</td><td>CEU5500000030</td><td>2016</td><td>M13</td><td>962.73</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000030</td><td>55</td><td>55000000</td><td>30</td><td>U</td><td>Average weekly earnings of production and nonsupervisory employees</td></tr><tr><td>3</td><td>CEU5500000031</td><td>2016</td><td>M13</td><td>411.29</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000031</td><td>55</td><td>55000000</td><td>31</td><td>U</td><td>Average weekly earnings of production and nonsupervisory employees</td></tr><tr><td>4</td><td>CEU5500000032</td><td>2016</td><td>M13</td><td>11.15</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000032</td><td>55</td><td>55000000</td><td>32</td><td>U</td><td>Average hourly earnings of production and nonsupervisory employees</td></tr><tr><td>5</td><td>CEU5500000034</td><td>2016</td><td>M13</td><td>111.6</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000034</td><td>55</td><td>55000000</td><td>34</td><td>U</td><td>Indexes of aggregate weekly hours of production and nonsupervisory employees</td></tr><tr><td>6</td><td>CEU5500000035</td><td>2016</td><td>M13</td><td>179.2</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000035</td><td>55</td><td>55000000</td><td>35</td><td>U</td><td>Indexes of aggregate weekly payrolls of production and nonsupervisory employees</td></tr><tr><td>7</td><td>CEU5500000081</td><td>2016</td><td>M13</td><td>236997</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000081</td><td>55</td><td>55000000</td><td>81</td><td>U</td><td>Aggregate weekly hours of production and nonsupervisory employees</td></tr><tr><td>8</td><td>CEU5500000082</td><td>2016</td><td>M13</td><td>6189003</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5500000082</td><td>55</td><td>55000000</td><td>82</td><td>U</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td></tr><tr><td>9</td><td>CEU5552200007</td><td>2016</td><td>M13</td><td>37.3</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td><td>CEU5552200007</td><td>55</td><td>55522000</td><td>7</td><td>U</td><td>Average weekly hours of production and nonsupervisory employees</td></tr></table>

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and datatype on data_type_code</span>

-- %%
SELECT TOP 10 s.data_type_code
FROM LaborStatisticsDB.dbo.series AS s
INNER JOIN LaborStatisticsDB.dbo.datatype AS dt
ON s.data_type_code = dt.data_type_code
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.038
-- <table><tr><th>data_type_code</th></tr><tr><td>1</td></tr><tr><td>10</td></tr><tr><td>25</td></tr><tr><td>26</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>6</td></tr><tr><td>7</td></tr><tr><td>8</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and industry on industry_code</span>

-- %%
SELECT TOP 10 s.industry_code
FROM LaborStatisticsDB.dbo.series AS s
LEFT JOIN LaborStatisticsDB.dbo.industry AS i
ON s.industry_code = i.industry_code
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.044
-- <table><tr><th>industry_code</th></tr><tr><td>00000000</td></tr><tr><td>00000000</td></tr><tr><td>00000000</td></tr><tr><td>00000000</td></tr><tr><td>05000000</td></tr><tr><td>05000000</td></tr><tr><td>05000000</td></tr><tr><td>05000000</td></tr><tr><td>05000000</td></tr><tr><td>05000000</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Aggregate Your Friends and Code some SQL</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Put together the following:</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp; No chopping people into little bits, please.</span>

-- %%
-- old solution
SELECT COUNT (*) AS "Number of Employees in 2016"
FROM LaborStatisticsDB.dbo.annual_2016 AS a
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.050
-- <table><tr><th>Number of Employees in 2016</th></tr><tr><td>29042</td></tr></table>

-- %%
-- new solution
SELECT ROUND(SUM(a.value),0) AS "Number of Employees in 2016"
FROM LaborStatisticsDB.dbo.annual_2016 AS a
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.044
-- <table><tr><th>Number of Employees in 2016</th></tr><tr><td>2351408916</td></tr></table>

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many women employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp;</span>

-- %%
-- step 1
SELECT TOP 10 a.series_id, s.series_title
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'women employee%'
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.051
-- <table><tr><th>series_id</th><th>series_title</th></tr><tr><td>CEU5000000010</td><td>Women employees</td></tr><tr><td>CEU5051100010</td><td>Women employees</td></tr><tr><td>CEU5051110010</td><td>Women employees</td></tr><tr><td>CEU5051111010</td><td>Women employees</td></tr><tr><td>CEU5051112010</td><td>Women employees</td></tr><tr><td>CEU5051113010</td><td>Women employees</td></tr><tr><td>CEU5051120010</td><td>Women employees</td></tr><tr><td>CEU5051200010</td><td>Women employees</td></tr><tr><td>CEU5051500010</td><td>Women employees</td></tr><tr><td>CEU5051511010</td><td>Women employees</td></tr></table>

-- %%
-- FINAL ANSWER --> 1372 women employees in 2016
SELECT COUNT(a.series_id) AS "Number of women employees in 2016"
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'women employee%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.058
-- <table><tr><th>Number of women employees in 2016</th></tr><tr><td>1372</td></tr></table>

-- %%
SELECT ROUND(SUM(a.series_id),0) AS "Number of women employees in 2016"
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'women employee%'
-- Out:
-- : Msg 8117, Level 16, State 1, Line 1
-- Operand data type nvarchar is invalid for sum operator.
-- Total execution time: 00:00:00.038

-- %%
-- new solution
SELECT ROUND(SUM(a.value),0) AS "Number of Employees in 2016"
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'women employee%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.062
-- <table><tr><th>Number of Employees in 2016</th></tr><tr><td>1125490</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many production/nonsupervisory employees were reported in 2016? Round to the nearest whole number.&nbsp;</span>

-- %%
-- step 1... checking all titles to see if exact word match
SELECT DISTINCT (s.series_title)
FROM LaborStatisticsDB.dbo.series AS s
-- Out:
-- (24 rows affected)
-- Total execution time: 00:00:00.054
-- <table><tr><th>series_title</th></tr><tr><td>Average hourly earnings of all employees</td></tr><tr><td>Average weekly hours of all employees</td></tr><tr><td>Average weekly overtime hours of production and nonsupervisory employees</td></tr><tr><td>Average weekly hours</td></tr><tr><td>Average weekly earnings of all employees</td></tr><tr><td>Average weekly overtime hours</td></tr><tr><td>Indexes of aggregate weekly payrolls of production and nonsupervisory employees</td></tr><tr><td>Women employees</td></tr><tr><td>Average weekly overtime hours of all employees</td></tr><tr><td>Average hourly earnings of production and nonsupervisory employees</td></tr><tr><td>Aggregate weekly hours of all employees</td></tr><tr><td>Indexes of aggregate weekly payrolls of all employees</td></tr><tr><td>Aggregate weekly payrolls of production and nonsupervisory employees</td></tr><tr><td>Diffusion indexes</td></tr><tr><td>Average weekly earnings of production and nonsupervisory employees</td></tr><tr><td>Indexes of aggregate weekly hours of all employees</td></tr><tr><td>Indexes of aggregate weekly hours of production and nonsupervisory employees</td></tr><tr><td>All employees</td></tr><tr><td>Aggregate weekly overtime hours of production and nonsupervisory employees</td></tr><tr><td>Aggregate weekly payrolls of all employees</td></tr><tr><td>Average weekly hours of production and nonsupervisory employees</td></tr><tr><td>Production and nonsupervisory employees</td></tr><tr><td>Aggregate weekly hours of production and nonsupervisory employees</td></tr><tr><td>Aggregate weekly overtime hours of all employees</td></tr></table>

-- %%
-- step 2...# total
SELECT COUNT(s.series_title) AS "Number of Production and nonsupervisory employees"
FROM LaborStatisticsDB.dbo.series AS s
WHERE s.series_title = 'Production and nonsupervisory employees'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.042
-- <table><tr><th>Number of Production and nonsupervisory employees</th></tr><tr><td>1102</td></tr></table>

-- %%
-- FINAL ANSWER --> 1102...but they shouldnt be the same?
SELECT COUNT(a.series_id) AS "Number of 'prod/nonsup employees in 2016' "
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'production and nonsupervisory employees%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.054
-- <table><tr><th>Number of 'prod/nonsup employees in 2016' </th></tr><tr><td>1102</td></tr></table>

-- %%
SELECT SUM(a.series_id) AS "Number of 'prod/nonsup employees in 2016' "
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'production and nonsupervisory employees%'
-- Out:
-- : Msg 8117, Level 16, State 1, Line 1
-- Operand data type nvarchar is invalid for sum operator.
-- Total execution time: 00:00:00.035

-- %%
-- new solution
SELECT ROUND(SUM(a.value),0) AS "Number of Employees in 2016"
FROM LaborStatisticsDB.dbo.annual_2016 AS a
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON a.series_id = s.series_id
WHERE s.series_title LIKE 'production and nonsupervisory employees%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.058
-- <table><tr><th>Number of Employees in 2016</th></tr><tr><td>1263650</td></tr></table>

-- %% [markdown]
-- 4. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, what is the average weekly hours worked by production and nonsupervisory employees across all industries?</span>

-- %%
SELECT ROUND(AVG(j.value), 2) AS "average weekly hours worked by production and nonsupervisory employees across all industries in 2017 "
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.datatype AS dt 
ON s.data_type_code = dt.data_type_code
WHERE dt.data_type_code = 7;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.064
-- <table><tr><th>average weekly hours worked by production and nonsupervisory employees across all industries in 2017 </th></tr><tr><td>36.06</td></tr></table>

-- %%
-- step 1.. looking at data
SELECT TOP 10 *
FROM LaborStatisticsDB.dbo.january_2017
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.034
-- <table><tr><th>id</th><th>series_id</th><th>year</th><th>period</th><th>value</th><th>footnote_codes</th><th>original_file</th></tr><tr><td>0</td><td>CES5500000007</td><td>2017</td><td>M01</td><td>36.9</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>1</td><td>CES5500000008</td><td>2017</td><td>M01</td><td>26.27</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>2</td><td>CES5500000030</td><td>2017</td><td>M01</td><td>969.36</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>3</td><td>CES5500000031</td><td>2017</td><td>M01</td><td>406.67</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>4</td><td>CES5500000032</td><td>2017</td><td>M01</td><td>11.02</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>5</td><td>CES5500000034</td><td>2017</td><td>M01</td><td>113.4</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>6</td><td>CES5500000035</td><td>2017</td><td>M01</td><td>183.3</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>7</td><td>CES5500000081</td><td>2017</td><td>M01</td><td>240920</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>8</td><td>CES5500000082</td><td>2017</td><td>M01</td><td>6328968</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>9</td><td>CES5552200007</td><td>2017</td><td>M01</td><td>37.5</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr></table>

-- %%
SELECT TOP 10 *
FROM LaborStatisticsDB.dbo.series AS s
WHERE s.series_title LIKE 'production and nonsupervisory employees%'
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.044
-- <table><tr><th>series_id</th><th>supersector_code</th><th>industry_code</th><th>data_type_code</th><th>seasonal</th><th>series_title</th></tr><tr><td>CES0500000006</td><td>5</td><td>05000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES0600000006</td><td>6</td><td>06000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES0800000006</td><td>8</td><td>08000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1000000006</td><td>10</td><td>10000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1011330006</td><td>10</td><td>10113300</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021000006</td><td>10</td><td>10210000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021100006</td><td>10</td><td>10211000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021200006</td><td>10</td><td>10212000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021210006</td><td>10</td><td>10212100</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021231006</td><td>10</td><td>10212310</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr></table>

-- %%
SELECT TOP 10 *
FROM LaborStatisticsDB.dbo.datatype AS dt
WHERE dt.data_type_text LIKE 'average weekly hours%'
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.039
-- <table><tr><th>data_type_code</th><th>data_type_text</th></tr><tr><td>2</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>7</td><td>AVERAGE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>19</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>36</td><td>AVERAGE WEEKLY HOURS</td></tr></table>

-- %%
SELECT COUNT(jan.series_id) AS "# prod/nonsup employees in 2017"
FROM LaborStatisticsDB.dbo.january_2017 AS jan
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON jan.series_id = s.series_id
WHERE s.series_title LIKE 'production and nonsupervisory employees%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.072
-- <table><tr><th># prod/nonsup employees in 2017</th></tr><tr><td>2204</td></tr></table>

-- %%
-- dtc has avg pay
SELECT COUNT (dt.data_type_code) 
FROM LaborStatisticsDB.dbo.datatype AS dt
LEFT JOIN LaborStatisticsDB.dbo.series AS s
ON dt.data_type_code = s.data_type_code
WHERE s.data_type_code = 8;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.045
-- <table><tr><th>(No column name)</th></tr><tr><td>1102</td></tr></table>

-- %% [markdown]
-- 5. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the total weekly payroll for production and nonsupervisory employees across all industries in January 2017? Round to the nearest penny, please.</span>

-- %%
-- **weekly payroll of all production and nonsupervisory employees across all industries in January 2017 --> 
SELECT TOP 1 (j.value) AS "total weekly payroll for production and nonsupervisory employees across all industries in January 2017"
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON s.series_id = j.series_id
JOIN LaborStatisticsDB.dbo.datatype AS dt
ON s.data_type_code = dt.data_type_code
WHERE dt.data_type_code = 82;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.043
-- <table><tr><th>total weekly payroll for production and nonsupervisory employees across all industries in January 2017</th></tr><tr><td>74498171</td></tr></table>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.datatype AS dt
WHERE dt.data_type_text LIKE '%employees%'
-- Out:
-- (33 rows affected)
-- Total execution time: 00:00:00.040
-- <table><tr><th>data_type_code</th><th>data_type_text</th></tr><tr><td>1</td><td>ALL EMPLOYEES</td></tr><tr><td>2</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>3</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>4</td><td>AVERAGE WEEKLY OVERTIME HOURS OF ALL EMPLOYEES</td></tr><tr><td>6</td><td>PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>7</td><td>AVERAGE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>8</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>9</td><td>AVERAGE WEEKLY OVERTIME HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>10</td><td>WOMEN EMPLOYEES</td></tr><tr><td>11</td><td>AVERAGE WEEKLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>12</td><td>AVERAGE WEEKLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>13</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>15</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>16</td><td>INDEXES OF AGGREGATE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>17</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>19</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>20</td><td>AVERAGE WEEKLY OVERTIME HOURS OF ALL EMPLOYEES</td></tr><tr><td>25</td><td>ALL EMPLOYEES</td></tr><tr><td>26</td><td>ALL EMPLOYEES</td></tr><tr><td>30</td><td>AVERAGE WEEKLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>31</td><td>AVERAGE WEEKLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>32</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>33</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>34</td><td>INDEXES OF AGGREGATE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>35</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>38</td><td>PRODUCTION AND NONSUPERVISORY EMPLOYEES-TO-ALL EMPLOYEES RATIO</td></tr><tr><td>39</td><td>WOMEN EMPLOYEES-TO-ALL EMPLOYEES RATIO</td></tr><tr><td>56</td><td>AGGREGATE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>57</td><td>AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>58</td><td>AGGREGATE WEEKLY OVERTIME HOURS OF ALL EMPLOYEES</td></tr><tr><td>81</td><td>AGGREGATE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>82</td><td>AGGREGATE WEEKLY PAYROLLS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>83</td><td>AGGREGATE WEEKLY OVERTIME HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr></table>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.datatype AS dt
WHERE dt.data_type_text LIKE '%weekly payroll%'
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.032
-- <table><tr><th>data_type_code</th><th>data_type_text</th></tr><tr><td>17</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>35</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>57</td><td>AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>82</td><td>AGGREGATE WEEKLY PAYROLLS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr></table>

-- %% [markdown]
-- 6. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, which industry was the average weekly hours worked by production and nonsupervisory employees the highest? Which industry was the lowest?</span>

-- %%
-- Highest avg weekly hours worked --> MOtor vehicle power train components
SELECT AVG(j.value) AS "avg weekly hours worked", i.industry_name AS "industry"
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i 
ON i.industry_code = s.industry_code
JOIN LaborStatisticsDB.dbo.datatype AS dt
ON dt.data_type_code = s.data_type_code
WHERE dt.data_type_code = 7
GROUP BY i.industry_name 
ORDER BY AVG(j.value) DESC
-- Out:
-- (501 rows affected)
-- Total execution time: 00:00:00.107
-- <table><tr><th>avg weekly hours worked</th><th>industry</th></tr><tr><td>49.6</td><td>Motor vehicle power train components</td></tr><tr><td>47.2</td><td>Support activities for mining</td></tr><tr><td>46.7</td><td>Support activities for oil and gas operations</td></tr><tr><td>46.699999999999996</td><td>Motor vehicle metal stamping</td></tr><tr><td>46.6</td><td>Coal mining</td></tr><tr><td>46.1</td><td>Oil and gas pipeline construction</td></tr><tr><td>46.025</td><td>Mining</td></tr><tr><td>45.7</td><td>Boilers</td></tr><tr><td>45.7</td><td>Crushed and broken limestone mining</td></tr><tr><td>45.65</td><td>Mining and logging</td></tr><tr><td>45.55</td><td>Stone mining and quarrying</td></tr><tr><td>45.35</td><td>Petroleum and coal products</td></tr><tr><td>45.15</td><td>Waste treatment and disposal</td></tr><tr><td>44.85</td><td>Basic chemicals</td></tr><tr><td>44.6</td><td>Motor vehicle parts</td></tr><tr><td>44.35</td><td>Rubber products</td></tr><tr><td>44.25</td><td>Pipeline transportation</td></tr><tr><td>44.15</td><td>Metal valves</td></tr><tr><td>44.1</td><td>Surgical appliances and supplies</td></tr><tr><td>44.05</td><td>Turbine and power transmission equipment</td></tr><tr><td>43.95</td><td>All other motor vehicle parts</td></tr><tr><td>43.849999999999994</td><td>Transportation equipment</td></tr><tr><td>43.8</td><td>Frozen food</td></tr><tr><td>43.75</td><td>Pulp</td></tr><tr><td>43.650000000000006</td><td>Motor vehicle gasoline engine and parts</td></tr><tr><td>43.65</td><td>Electric power transmission and distribution</td></tr><tr><td>43.65</td><td>Power generation and supply</td></tr><tr><td>43.6</td><td>Power and communication system construction</td></tr><tr><td>43.55</td><td>Other heavy construction</td></tr><tr><td>43.55</td><td>Corrugated and solid fiber boxes</td></tr><tr><td>43.5</td><td>Special tools</td></tr><tr><td>43.45</td><td>Aerospace products and parts</td></tr><tr><td>43.45</td><td>Animal slaughtering and processing</td></tr><tr><td>43.45</td><td>Fossil fuel electric power generation</td></tr><tr><td>43.375</td><td>Other specialized trucking</td></tr><tr><td>43.3</td><td>Utility system construction</td></tr><tr><td>43.25</td><td>Other electrical equipment and components</td></tr><tr><td>43.2</td><td>HVAC and commercial refrigeration equipment</td></tr><tr><td>43.15</td><td>Electric power generation</td></tr><tr><td>43.15</td><td>Oil and gas extraction</td></tr><tr><td>43.15</td><td>Paperboard containers</td></tr><tr><td>43.05</td><td>Utilities</td></tr><tr><td>43</td><td>Forging and stamping</td></tr><tr><td>42.9</td><td>Heavy and civil engineering construction</td></tr><tr><td>42.8</td><td>Electrical equipment and appliances</td></tr><tr><td>42.8</td><td>Turned products and screws</td></tr><tr><td>42.8</td><td>Sawmills and wood preservation</td></tr><tr><td>42.75</td><td>Petroleum</td></tr><tr><td>42.75</td><td>Metalworking machinery</td></tr><tr><td>42.75</td><td>Machinery</td></tr><tr><td>42.65</td><td>Fruit and vegetable preserving and specialty</td></tr><tr><td>42.6</td><td>Other general purpose machinery</td></tr><tr><td>42.55</td><td>Primary metals</td></tr><tr><td>42.55</td><td>Electrical equipment</td></tr><tr><td>42.5</td><td>Plastics and rubber products</td></tr><tr><td>42.45</td><td>Other fabricated metal products</td></tr><tr><td>42.45</td><td>Aircraft</td></tr><tr><td>42.4</td><td>Agricultural</td></tr><tr><td>42.4</td><td>Construction equipment</td></tr><tr><td>42.4</td><td>Highway</td></tr><tr><td>42.3</td><td>Cement and concrete products</td></tr><tr><td>42.2</td><td>Poultry processing</td></tr><tr><td>42.1</td><td>Converted paper products</td></tr><tr><td>42.1</td><td>Machine shops and threaded products</td></tr><tr><td>42.1</td><td>Medical equipment and supplies</td></tr><tr><td>42.099999999999994</td><td>Plastics packaging materials</td></tr><tr><td>42.05</td><td>Fruits and vegetables</td></tr><tr><td>42.05</td><td>Fabricated metal products</td></tr><tr><td>42</td><td>Resin</td></ ...

-- %%
-- new solution
SELECT TOP 1 MAX(j.value) AS "Max weekly hours worked", i.industry_name AS "industry"
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i 
ON i.industry_code = s.industry_code
JOIN LaborStatisticsDB.dbo.datatype AS dt
ON dt.data_type_code = s.data_type_code
WHERE dt.data_type_code = 7
GROUP BY i.industry_name 
ORDER BY AVG(j.value) DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.127
-- <table><tr><th>Max weekly hours worked</th><th>industry</th></tr><tr><td>49.8</td><td>Motor vehicle power train components</td></tr></table>

-- %%
-- new solution
SELECT TOP 1 MIN(j.value) AS "Min weekly hours worked", i.industry_name AS "industry"
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i 
ON i.industry_code = s.industry_code
JOIN LaborStatisticsDB.dbo.datatype AS dt
ON dt.data_type_code = s.data_type_code
WHERE dt.data_type_code = 7
GROUP BY i.industry_name 
ORDER BY AVG(j.value) ASC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.079
-- <table><tr><th>Min weekly hours worked</th><th>industry</th></tr><tr><td>16.7</td><td>Fitness and recreational sports centers</td></tr></table>

-- %%
-- Lowest avg weekly hours worked --> fitness and recreational sports centers
SELECT AVG(j.value) AS "avg weekly hours worked", i.industry_name AS "industry"
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i 
ON i.industry_code = s.industry_code
JOIN LaborStatisticsDB.dbo.datatype AS dt
ON dt.data_type_code = s.data_type_code
WHERE dt.data_type_code = 7
GROUP BY i.industry_name 
ORDER BY AVG(j.value) ASC
-- Out:
-- (501 rows affected)
-- Total execution time: 00:00:00.113
-- <table><tr><th>avg weekly hours worked</th><th>industry</th></tr><tr><td>16.85</td><td>Fitness and recreational sports centers</td></tr><tr><td>18.3</td><td>Civic and social organizations</td></tr><tr><td>18.8</td><td>Family clothing stores</td></tr><tr><td>18.8</td><td>Women's clothing stores</td></tr><tr><td>19.3</td><td>Skiing facilities</td></tr><tr><td>19.6</td><td>Clothing stores</td></tr><tr><td>20.2</td><td>Bowling centers</td></tr><tr><td>21.2</td><td>Clothing accessories stores</td></tr><tr><td>21.3</td><td>Clothing and clothing accessories stores</td></tr><tr><td>21.35</td><td>Drinking places</td></tr><tr><td>21.85</td><td>Amusements</td></tr><tr><td>22.6</td><td>Snack and nonalcoholic beverage bars</td></tr><tr><td>22.9</td><td>Other personal care services</td></tr><tr><td>22.9</td><td>Arts</td></tr><tr><td>23</td><td>Gift</td></tr><tr><td>23.6</td><td>Shoe stores</td></tr><tr><td>23.8</td><td>Book stores and news dealers</td></tr><tr><td>24.1</td><td>Restaurants and other eating places</td></tr><tr><td>24.15</td><td>Food services and drinking places</td></tr><tr><td>24.15</td><td>Limited-service restaurants</td></tr><tr><td>24.299999999999997</td><td>Full-service restaurants</td></tr><tr><td>24.349999999999998</td><td>Other home furnishings stores</td></tr><tr><td>24.55</td><td>Leisure and hospitality</td></tr><tr><td>24.650000000000002</td><td>Performing arts companies</td></tr><tr><td>24.75</td><td>Personal care services</td></tr><tr><td>24.9</td><td>Accommodation and food services</td></tr><tr><td>25</td><td>Museums</td></tr><tr><td>25.049999999999997</td><td>Golf courses and country clubs</td></tr><tr><td>25.2</td><td>Special food services</td></tr><tr><td>25.3</td><td>Hair</td></tr><tr><td>25.549999999999997</td><td>Office supplies</td></tr><tr><td>25.75</td><td>Pet care services</td></tr><tr><td>25.75</td><td>Performing arts and spectator sports</td></tr><tr><td>25.75</td><td>Hobby</td></tr><tr><td>25.85</td><td>Sporting goods and musical instrument stores</td></tr><tr><td>25.900000000000002</td><td>Sporting goods stores</td></tr><tr><td>26</td><td>Florists</td></tr><tr><td>26.049999999999997</td><td>Offices of chiropractors</td></tr><tr><td>26.3</td><td>Coin-operated laundries and drycleaners</td></tr><tr><td>26.4</td><td>Cafeterias</td></tr><tr><td>26.450000000000003</td><td>Beer</td></tr><tr><td>26.65</td><td>RV parks and recreational camps</td></tr><tr><td>26.75</td><td>Offices of mental health practitioners</td></tr><tr><td>26.849999999999998</td><td>Car washes</td></tr><tr><td>26.95</td><td>Other personal services</td></tr><tr><td>27.05</td><td>Motion picture and sound recording industries</td></tr><tr><td>27.200000000000003</td><td>Janitorial services</td></tr><tr><td>27.200000000000003</td><td>Services for the elderly and persons with disabilities</td></tr><tr><td>27.25</td><td>Social science and humanities research</td></tr><tr><td>27.3</td><td>Personal and laundry services</td></tr><tr><td>27.5</td><td>Home furnishings stores</td></tr><tr><td>27.6</td><td>Spectator sports</td></tr><tr><td>27.65</td><td>Offices of dentists</td></tr><tr><td>27.65</td><td>Food service contractors</td></tr><tr><td>27.75</td><td>Specialty food stores</td></tr><tr><td>27.8</td><td>Miscellaneous store retailers</td></tr><tr><td>27.85</td><td>Offices of other health practitioners</td></tr><tr><td>27.95</td><td>Food and beverage stores</td></tr><tr><td>27.950000000000003</td><td>Freestanding emergency medical centers</td></tr><tr><td>27.950000000000003</td><td>Individual and family services</td></tr><tr><td>27.950000000000003</td><td>Marketing research and public opinion polling</td></tr><tr><td>27.950000000000003</td><td>Supermarkets and other grocery stores</td></tr><tr><td>28.049999999999997</td><td>Grocery stores</td></tr><tr><td>28.1</td><td>Independent artists</td></tr><tr><td>28.1</td><td>Offices of specialty therapists</td></tr><tr><td>28.200000000000003</td><td>Offices of all other health practitioners</td></tr><tr ...

-- %%
SELECT * 
FROM LaborStatisticsDB.dbo.series AS s 
WHERE s.series_title LIKE 'production and nonsupervisory employees%'
-- Out:
-- (1102 rows affected)
-- Total execution time: 00:00:00.132
-- <table><tr><th>series_id</th><th>supersector_code</th><th>industry_code</th><th>data_type_code</th><th>seasonal</th><th>series_title</th></tr><tr><td>CES0500000006</td><td>5</td><td>05000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES0600000006</td><td>6</td><td>06000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES0800000006</td><td>8</td><td>08000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1000000006</td><td>10</td><td>10000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1011330006</td><td>10</td><td>10113300</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021000006</td><td>10</td><td>10210000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021100006</td><td>10</td><td>10211000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021200006</td><td>10</td><td>10212000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021210006</td><td>10</td><td>10212100</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021231006</td><td>10</td><td>10212310</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021231206</td><td>10</td><td>10212312</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021231906</td><td>10</td><td>10212319</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021300006</td><td>10</td><td>10213000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES1021311206</td><td>10</td><td>10213112</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2000000006</td><td>20</td><td>20000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023600006</td><td>20</td><td>20236000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023610006</td><td>20</td><td>20236100</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023611506</td><td>20</td><td>20236115</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023611806</td><td>20</td><td>20236118</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023620006</td><td>20</td><td>20236200</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023621006</td><td>20</td><td>20236210</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023622006</td><td>20</td><td>20236220</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023700006</td><td>20</td><td>20237000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023710006</td><td>20</td><td>20237100</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023711006</td><td>20</td><td>20237110</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023712006</td><td>20</td><td>20237120</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023713006</td><td>20</td><td>20237130</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023720006</td><td>20</td><td>20237200</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023730006</td><td>20</td><td>20237300</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023790006</td><td>20</td><td>20237900</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td></tr><tr><td>CES2023800006</td><td>20</td><td>20238000</ ...

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.datatype AS dt
-- Out:
-- (45 rows affected)
-- Total execution time: 00:00:00.040
-- <table><tr><th>data_type_code</th><th>data_type_text</th></tr><tr><td>1</td><td>ALL EMPLOYEES</td></tr><tr><td>2</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>3</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>4</td><td>AVERAGE WEEKLY OVERTIME HOURS OF ALL EMPLOYEES</td></tr><tr><td>6</td><td>PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>7</td><td>AVERAGE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>8</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>9</td><td>AVERAGE WEEKLY OVERTIME HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>10</td><td>WOMEN EMPLOYEES</td></tr><tr><td>11</td><td>AVERAGE WEEKLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>12</td><td>AVERAGE WEEKLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>13</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>15</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>16</td><td>INDEXES OF AGGREGATE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>17</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>19</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>20</td><td>AVERAGE WEEKLY OVERTIME HOURS OF ALL EMPLOYEES</td></tr><tr><td>21</td><td>DIFFUSION INDEXES</td></tr><tr><td>22</td><td>DIFFUSION INDEXES</td></tr><tr><td>23</td><td>DIFFUSION INDEXES</td></tr><tr><td>24</td><td>DIFFUSION INDEXES</td></tr><tr><td>25</td><td>ALL EMPLOYEES</td></tr><tr><td>26</td><td>ALL EMPLOYEES</td></tr><tr><td>30</td><td>AVERAGE WEEKLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>31</td><td>AVERAGE WEEKLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>32</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>33</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>34</td><td>INDEXES OF AGGREGATE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>35</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>36</td><td>AVERAGE WEEKLY HOURS</td></tr><tr><td>37</td><td>AVERAGE WEEKLY OVERTIME HOURS</td></tr><tr><td>38</td><td>PRODUCTION AND NONSUPERVISORY EMPLOYEES-TO-ALL EMPLOYEES RATIO</td></tr><tr><td>39</td><td>WOMEN EMPLOYEES-TO-ALL EMPLOYEES RATIO</td></tr><tr><td>56</td><td>AGGREGATE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>57</td><td>AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>58</td><td>AGGREGATE WEEKLY OVERTIME HOURS OF ALL EMPLOYEES</td></tr><tr><td>81</td><td>AGGREGATE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>82</td><td>AGGREGATE WEEKLY PAYROLLS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>83</td><td>AGGREGATE WEEKLY OVERTIME HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>86</td><td>1-MONTH CONFIDENCE INTERVAL</td></tr><tr><td>87</td><td>3-MONTH CONFIDENCE INTERVAL</td></tr><tr><td>88</td><td>6-MONTH CONFIDENCE INTERVAL</td></tr><tr><td>89</td><td>12-MONTH CONFIDENCE INTERVAL</td></tr><tr><td>98</td><td>CPI-U 1982-84</td></tr><tr><td>99</td><td>CPI-W 1982-84</td></tr></table>

-- %%
-- 
SELECT TOP 10 *
FROM LaborStatisticsDB.dbo.january_2017
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.035
-- <table><tr><th>id</th><th>series_id</th><th>year</th><th>period</th><th>value</th><th>footnote_codes</th><th>original_file</th></tr><tr><td>0</td><td>CES5500000007</td><td>2017</td><td>M01</td><td>36.9</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>1</td><td>CES5500000008</td><td>2017</td><td>M01</td><td>26.27</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>2</td><td>CES5500000030</td><td>2017</td><td>M01</td><td>969.36</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>3</td><td>CES5500000031</td><td>2017</td><td>M01</td><td>406.67</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>4</td><td>CES5500000032</td><td>2017</td><td>M01</td><td>11.02</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>5</td><td>CES5500000034</td><td>2017</td><td>M01</td><td>113.4</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>6</td><td>CES5500000035</td><td>2017</td><td>M01</td><td>183.3</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>7</td><td>CES5500000081</td><td>2017</td><td>M01</td><td>240920</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>8</td><td>CES5500000082</td><td>2017</td><td>M01</td><td>6328968</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr><tr><td>9</td><td>CES5552200007</td><td>2017</td><td>M01</td><td>37.5</td><td>NULL</td><td>ce.data.55c.FinancialActivities.ProductionEmployeeHoursAndEarnings.csv</td></tr></table>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.industry
-- Out:
-- (915 rows affected)
-- Total execution time: 00:00:00.110
-- <table><tr><th>id</th><th>industry_code</th><th>naics_code</th><th>publishing_status</th><th>industry_name</th><th>display_level</th><th>selectable</th><th>sort_sequence</th></tr><tr><td>0</td><td>0</td><td>-</td><td>B</td><td>Total nonfarm</td><td>0</td><td>T</td><td>1</td></tr><tr><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>2</td><td>6000000</td><td>-</td><td>A</td><td>Goods-producing</td><td>1</td><td>T</td><td>3</td></tr><tr><td>3</td><td>7000000</td><td>-</td><td>B</td><td>Service-providing</td><td>1</td><td>T</td><td>4</td></tr><tr><td>4</td><td>8000000</td><td>-</td><td>A</td><td>Private service-providing</td><td>1</td><td>T</td><td>5</td></tr><tr><td>5</td><td>10000000</td><td>-</td><td>A</td><td>Mining and logging</td><td>2</td><td>T</td><td>6</td></tr><tr><td>6</td><td>10113300</td><td>1133</td><td>A</td><td>Logging</td><td>5</td><td>T</td><td>7</td></tr><tr><td>7</td><td>10210000</td><td>21</td><td>A</td><td>Mining</td><td>3</td><td>T</td><td>8</td></tr><tr><td>8</td><td>10211000</td><td>211</td><td>A</td><td>Oil and gas extraction</td><td>4</td><td>T</td><td>9</td></tr><tr><td>9</td><td>10212000</td><td>212</td><td>A</td><td>Mining</td><td>NULL</td><td>NULL</td><td>NULL</td></tr><tr><td>10</td><td>10212100</td><td>2121</td><td>A</td><td>Coal mining</td><td>5</td><td>T</td><td>11</td></tr><tr><td>11</td><td>10212111</td><td>212111</td><td>C</td><td>Bituminous coal and lignite surface mining</td><td>7</td><td>T</td><td>12</td></tr><tr><td>12</td><td>10212113</td><td>212112</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td></tr><tr><td>13</td><td>10212200</td><td>2122</td><td>E</td><td>Metal ore mining</td><td>5</td><td>T</td><td>14</td></tr><tr><td>14</td><td>10212300</td><td>2123</td><td>E</td><td>Nonmetallic mineral mining and quarrying</td><td>5</td><td>T</td><td>15</td></tr><tr><td>15</td><td>10212310</td><td>21231</td><td>A</td><td>Stone mining and quarrying</td><td>6</td><td>T</td><td>16</td></tr><tr><td>16</td><td>10212312</td><td>212312</td><td>A</td><td>Crushed and broken limestone mining</td><td>7</td><td>T</td><td>17</td></tr><tr><td>17</td><td>10212319</td><td>212311</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td></tr><tr><td>18</td><td>10212320</td><td>21232</td><td>C</td><td>Sand</td><td>NULL</td><td>NULL</td><td>NULL</td></tr><tr><td>19</td><td>10212321</td><td>212321</td><td>B</td><td>Construction sand and gravel mining</td><td>7</td><td>T</td><td>20</td></tr><tr><td>20</td><td>10212390</td><td>21239</td><td>C</td><td>Other nonmetallic mineral mining</td><td>6</td><td>T</td><td>21</td></tr><tr><td>21</td><td>10213000</td><td>213</td><td>A</td><td>Support activities for mining</td><td>4</td><td>T</td><td>22</td></tr><tr><td>22</td><td>10213112</td><td>213112</td><td>A</td><td>Support activities for oil and gas operations</td><td>7</td><td>T</td><td>23</td></tr><tr><td>23</td><td>20000000</td><td>23</td><td>A</td><td>Construction</td><td>2</td><td>T</td><td>24</td></tr><tr><td>24</td><td>20236000</td><td>236</td><td>A</td><td>Construction of buildings</td><td>4</td><td>T</td><td>25</td></tr><tr><td>25</td><td>20236100</td><td>2361</td><td>A</td><td>Residential building</td><td>5</td><td>T</td><td>26</td></tr><tr><td>26</td><td>20236115</td><td>236115</td><td>A</td><td>New single-family general contractors</td><td>7</td><td>T</td><td>27</td></tr><tr><td>27</td><td>20236116</td><td>236116</td><td>B</td><td>New multifamily general contractors</td><td>7</td><td>T</td><td>28</td></tr><tr><td>28</td><td>20236117</td><td>236117</td><td>B</td><td>New housing operative builders</td><td>7</td><td>T</td><td>29</td></tr><tr><td>29</td><td>20236118</td><td>236118</td><td>A</td><td>Residential remodelers</td><td>7</td><td>T</td><td>30</td></tr><tr><td>30</td><td>20236200</td><td>2362</td><td>A</td><td>Nonresidential building</td><td>5</td><td>T</td><td>31</td></tr><tr><td>31</td><td>20236210</td><td>23621</td>< ...

-- %% [markdown]
-- 7. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2021, which industry was the total weekly payroll for production and nonsupervisory employees the highest? Which industry was the lowest?</span>

-- %%
-- new solution
-- Highest industry payroll --> total private
SELECT TOP 1 ROUND(SUM(j.value),0) AS "total weekly payroll", i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i
ON i.industry_code = s.industry_code
WHERE s.data_type_code = 30
GROUP BY i.industry_name
ORDER BY SUM(j.value) DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.064
-- <table><tr><th>total weekly payroll</th><th>industry_name</th></tr><tr><td>119157</td><td>NULL</td></tr></table>

-- %%
SELECT TOP 1 MAX(j.value) AS "total weekly payroll", i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i
ON i.industry_code = s.industry_code
WHERE s.data_type_code = 30
GROUP BY i.industry_name
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.525
-- <table><tr><th>total weekly payroll</th><th>industry_name</th></tr><tr><td>1655.98</td><td>NULL</td></tr></table>

-- %%
SELECT TOP 1 MIN(j.value) AS "total weekly payroll", i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i
ON i.industry_code = s.industry_code
WHERE s.data_type_code = 30
GROUP BY i.industry_name
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.419
-- <table><tr><th>total weekly payroll</th><th>industry_name</th></tr><tr><td>295.46</td><td>NULL</td></tr></table>

-- %%
-- new solution
-- Lowest industry payroll
SELECT TOP 1 SUM(j.value) AS "total weekly payroll", i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i
ON i.industry_code = s.industry_code
WHERE s.data_type_code = 30
GROUP BY i.industry_name
ORDER BY SUM(j.value) ASC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.073
-- <table><tr><th>total weekly payroll</th><th>industry_name</th></tr><tr><td>938.5</td><td>Bowling centers</td></tr></table>

-- %%
-- Lowest industry payroll --> coin operated laundries
SELECT TOP 1 SUM(j.value) AS "total weekly payroll", i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
JOIN LaborStatisticsDB.dbo.industry AS i
ON i.industry_code = s.industry_code
WHERE s.data_type_code = 82
GROUP BY i.industry_name
ORDER BY SUM(j.value) ASC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.088
-- <table><tr><th>total weekly payroll</th><th>industry_name</th></tr><tr><td>40448</td><td>Coin-operated laundries and drycleaners</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Subqueries, Unions, Derived Tables, Oh My!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Write a query that returns the series_id, industry_code, industry_name, and value from the january_2017 table but only if that value is greater than the average value for annual_2016 of data_type_code 82.</span>

-- %%
SELECT j.series_id, i.industry_code, i.industry_name, j.value
FROM LaborStatisticsDB.dbo.january_2017 AS j, LaborStatisticsDB.dbo.industry AS i
WHERE j.series_id = s.series_id AND s.industry_code = i.industry_code
AND s.data_type_code = 82 AND j.value > (
    SELECT AVG(a.value)
    FROM LaborStatisticsDB.dbo.annual_2016 AS a 
    WHERE a.series_id IN (
        FROM LaborStatisticsDB.dbo.series AS s 
        WHERE s.data_type_code = 82

    )
)
GROUP BY j.series_id, i.industry_code, i.industry_name, j.value
-- Out:
-- : Msg 156, Level 15, State 1, Line 8
-- Incorrect syntax near the keyword 'FROM'.
-- Total execution time: 00:00:00.036

-- %%
SELECT s.series_id, i.industry_code, i.industry_name, j.value 
FROM LaborStatisticsDB.dbo.industry AS i 
JOIN LaborStatisticsDB.dbo.series AS s 
ON i.industry_code = s.industry_code
JOIN LaborStatisticsDB.dbo.january_2017 AS j 
ON 
WHERE j.value > AVG(a.value) AND s.data_type_code = 82;

-- %%
SELECT s.series_id, i.industry_code, i.industry_name, j.value 
FROM LaborStatisticsDB.dbo.january_2017 AS j 
WHERE j.value > (
    SELECT AVG(a.value)
    FROM LaborStatisticsDB.dbo.annual_2016 AS a
    WHERE s.data_type_code = 82
)

JOIN LaborStatisticsDB.dbo.industry AS i 
ON i.industry_code = s.industry_code
-- Out:
-- : Msg 156, Level 15, State 1, Line 7
-- Incorrect syntax near the keyword 'WHERE'.
-- Total execution time: 00:00:00.185

-- %%
SELECT s.series_id, i.industry_code, i.industry_name
FROM LaborStatisticsDB.dbo.series AS s 
JOIN LaborStatisticsDB.dbo.industry AS i 
ON s.industry_code = i.industry_code
WHERE s.series_id IN (
    SELECT j.series_id
    FROM LaborStatisticsDB.dbo.january_2017 AS j 
    WHERE j.value > (
        SELECT AVG(a.value)
        FROM LaborStatisticsDB.dbo.annual_2016 AS a
        WHERE s.data_type_code = 82) 
);
-- Out:
-- (723 rows affected)
-- Total execution time: 00:00:06.707
-- <table><tr><th>series_id</th><th>industry_code</th><th>industry_name</th></tr><tr><td>CES0500000082</td><td>5000000</td><td>Total private</td></tr><tr><td>CES0600000082</td><td>6000000</td><td>Goods-producing</td></tr><tr><td>CES0800000082</td><td>8000000</td><td>Private service-providing</td></tr><tr><td>CES1000000082</td><td>10000000</td><td>Mining and logging</td></tr><tr><td>CES1021000082</td><td>10210000</td><td>Mining</td></tr><tr><td>CES1021100082</td><td>10211000</td><td>Oil and gas extraction</td></tr><tr><td>CES1021200082</td><td>10212000</td><td>Mining</td></tr><tr><td>CES1021300082</td><td>10213000</td><td>Support activities for mining</td></tr><tr><td>CES1021311282</td><td>10213112</td><td>Support activities for oil and gas operations</td></tr><tr><td>CES2000000082</td><td>20000000</td><td>Construction</td></tr><tr><td>CES2023600082</td><td>20236000</td><td>Construction of buildings</td></tr><tr><td>CES2023610082</td><td>20236100</td><td>Residential building</td></tr><tr><td>CES2023611582</td><td>20236115</td><td>New single-family general contractors</td></tr><tr><td>CES2023611882</td><td>20236118</td><td>Residential remodelers</td></tr><tr><td>CES2023620082</td><td>20236200</td><td>Nonresidential building</td></tr><tr><td>CES2023621082</td><td>20236210</td><td>Industrial building</td></tr><tr><td>CES2023622082</td><td>20236220</td><td>Commercial building</td></tr><tr><td>CES2023700082</td><td>20237000</td><td>Heavy and civil engineering construction</td></tr><tr><td>CES2023710082</td><td>20237100</td><td>Utility system construction</td></tr><tr><td>CES2023711082</td><td>20237110</td><td>Water and sewer system construction</td></tr><tr><td>CES2023712082</td><td>20237120</td><td>Oil and gas pipeline construction</td></tr><tr><td>CES2023713082</td><td>20237130</td><td>Power and communication system construction</td></tr><tr><td>CES2023730082</td><td>20237300</td><td>Highway</td></tr><tr><td>CES2023790082</td><td>20237900</td><td>Other heavy construction</td></tr><tr><td>CES2023800082</td><td>20238000</td><td>Specialty trade contractors</td></tr><tr><td>CES2023810082</td><td>20238100</td><td>Building foundation and exterior contractors</td></tr><tr><td>CES2023811082</td><td>20238110</td><td>Poured concrete structure contractors</td></tr><tr><td>CES2023812082</td><td>20238120</td><td>Steel and precast concrete contractors</td></tr><tr><td>CES2023814082</td><td>20238140</td><td>Masonry contractors</td></tr><tr><td>CES2023816082</td><td>20238160</td><td>Roofing contractors</td></tr><tr><td>CES2023820082</td><td>20238200</td><td>Building equipment contractors</td></tr><tr><td>CES2023821082</td><td>20238210</td><td>Electrical contractors</td></tr><tr><td>CES2023822082</td><td>20238220</td><td>Plumbing and HVAC contractors</td></tr><tr><td>CES2023829082</td><td>20238290</td><td>Other building equipment contractors</td></tr><tr><td>CES2023830082</td><td>20238300</td><td>Building finishing contractors</td></tr><tr><td>CES2023831082</td><td>20238310</td><td>Drywall and insulation contractors</td></tr><tr><td>CES2023832082</td><td>20238320</td><td>Painting and wall covering contractors</td></tr><tr><td>CES2023835082</td><td>20238350</td><td>Finish carpentry contractors</td></tr><tr><td>CES2023890082</td><td>20238900</td><td>Other specialty trade contractors</td></tr><tr><td>CES2023891082</td><td>20238910</td><td>Site preparation contractors</td></tr><tr><td>CES2023899082</td><td>20238990</td><td>All other specialty trade contractors</td></tr><tr><td>CES3000000082</td><td>30000000</td><td>Manufacturing</td></tr><tr><td>CES3100000082</td><td>31000000</td><td>Durable goods</td></tr><tr><td>CES3132100082</td><td>31321000</td><td>Wood products</td></tr><tr><td>CES3132190082</td><td>31321900</td><td>Other wood products</td></tr><tr><td>CES3132700082</td><td>31327000</td><td>Nonmetallic mineral products</td></tr><tr><td>CES3132730082</td><td>31327300</td><td>Cement and concrete products</td></tr><tr><td>CES3133100082</td><td>31331000 ...

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Create a Union table comparing average weekly earnings&nbsp; of production and nonsupervisory employees between annual_16 and january_17 using the data type 30.&nbsp; Round to the nearest penny.&nbsp; You should have a column for the average earnings and a column for the year, and the period.</span>

-- %%
-- new solution
SELECT a.value, a.year, a.period
FROM LaborStatisticsDB.dbo.annual_2016 AS a
INNER JOIN LaborStatisticsDB.dbo.series AS s on
s.series_id = a. series_id
WHERE s.data_type_code = 30
UNION
SELECT j.VALUE, j.YEAR, j.PERIOD
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s on
s.series_id = j.series_id
WHERE s.data_type_code = 30
-- Out:
-- (1642 rows affected)
-- Total execution time: 00:00:00.117
-- <table><tr><th>value</th><th>year</th><th>period</th></tr><tr><td>231.47</td><td>2016</td><td>M13</td></tr><tr><td>232</td><td>2017</td><td>M01</td></tr><tr><td>233.2</td><td>2016</td><td>M13</td></tr><tr><td>235.14</td><td>2017</td><td>M01</td></tr><tr><td>237.25</td><td>2017</td><td>M01</td></tr><tr><td>238.74</td><td>2017</td><td>M01</td></tr><tr><td>244.17</td><td>2016</td><td>M13</td></tr><tr><td>244.49</td><td>2017</td><td>M01</td></tr><tr><td>245.14</td><td>2017</td><td>M01</td></tr><tr><td>245.68</td><td>2016</td><td>M13</td></tr><tr><td>249.42</td><td>2017</td><td>M01</td></tr><tr><td>251.75</td><td>2017</td><td>M01</td></tr><tr><td>252.65</td><td>2017</td><td>M01</td></tr><tr><td>252.72</td><td>2017</td><td>M01</td></tr><tr><td>255.04</td><td>2016</td><td>M13</td></tr><tr><td>255.29</td><td>2017</td><td>M01</td></tr><tr><td>256.49</td><td>2016</td><td>M13</td></tr><tr><td>256.66</td><td>2016</td><td>M13</td></tr><tr><td>256.94</td><td>2016</td><td>M13</td></tr><tr><td>259.62</td><td>2017</td><td>M01</td></tr><tr><td>261.56</td><td>2016</td><td>M13</td></tr><tr><td>262.2</td><td>2017</td><td>M01</td></tr><tr><td>264.51</td><td>2017</td><td>M01</td></tr><tr><td>266.16</td><td>2016</td><td>M13</td></tr><tr><td>269.7</td><td>2017</td><td>M01</td></tr><tr><td>270.12</td><td>2017</td><td>M01</td></tr><tr><td>272.88</td><td>2017</td><td>M01</td></tr><tr><td>273.67</td><td>2017</td><td>M01</td></tr><tr><td>274.25</td><td>2017</td><td>M01</td></tr><tr><td>276.64</td><td>2017</td><td>M01</td></tr><tr><td>276.94</td><td>2016</td><td>M13</td></tr><tr><td>278.21</td><td>2017</td><td>M01</td></tr><tr><td>280.73</td><td>2016</td><td>M13</td></tr><tr><td>281.31</td><td>2017</td><td>M01</td></tr><tr><td>286.66</td><td>2017</td><td>M01</td></tr><tr><td>287.63</td><td>2016</td><td>M13</td></tr><tr><td>288.22</td><td>2017</td><td>M01</td></tr><tr><td>289.89</td><td>2017</td><td>M01</td></tr><tr><td>291.16</td><td>2017</td><td>M01</td></tr><tr><td>291.68</td><td>2016</td><td>M13</td></tr><tr><td>292.16</td><td>2016</td><td>M13</td></tr><tr><td>292.28</td><td>2017</td><td>M01</td></tr><tr><td>293.39</td><td>2017</td><td>M01</td></tr><tr><td>293.49</td><td>2017</td><td>M01</td></tr><tr><td>295.24</td><td>2017</td><td>M01</td></tr><tr><td>295.46</td><td>2017</td><td>M01</td></tr><tr><td>299.88</td><td>2017</td><td>M01</td></tr><tr><td>302</td><td>2017</td><td>M01</td></tr><tr><td>303.92</td><td>2017</td><td>M01</td></tr><tr><td>307.07</td><td>2016</td><td>M13</td></tr><tr><td>309.16</td><td>2017</td><td>M01</td></tr><tr><td>309.92</td><td>2016</td><td>M13</td></tr><tr><td>310.12</td><td>2016</td><td>M13</td></tr><tr><td>310.7</td><td>2017</td><td>M01</td></tr><tr><td>311.17</td><td>2017</td><td>M01</td></tr><tr><td>311.42</td><td>2016</td><td>M13</td></tr><tr><td>313.14</td><td>2016</td><td>M13</td></tr><tr><td>315</td><td>2017</td><td>M01</td></tr><tr><td>315.24</td><td>2017</td><td>M01</td></tr><tr><td>316.06</td><td>2017</td><td>M01</td></tr><tr><td>317.78</td><td>2016</td><td>M13</td></tr><tr><td>317.85</td><td>2016</td><td>M13</td></tr><tr><td>318.02</td><td>2017</td><td>M01</td></tr><tr><td>318.24</td><td>2017</td><td>M01</td></tr><tr><td>318.52</td><td>2016</td><td>M13</td></tr><tr><td>319.46</td><td>2017</td><td>M01</td></tr><tr><td>319.52</td><td>2016</td><td>M13</td></tr><tr><td>320.4</td><td>2017</td><td>M01</td></tr><tr><td>320.52</td><td>2017</td><td>M01</td></tr><tr><td>321.44</td><td>2016</td><td>M13</td></tr><tr><td>323.01</td><td>2017</td><td>M01</td></tr><tr><td>323.52</td><td>2017</td><td>M01</td></tr><tr><td>324.19</td><td>2016</td><td>M13</td></tr><tr><td>326.37</td><td>2017</td><td>M01</td></tr><tr><td>326.71</td><td>2017</td><td>M01</td></tr><tr><td>328.24</td><td>2017</td><td>M01</td></tr><tr><td>329.4</td><td>2017</td><td>M01</td></tr><tr><td>330.53</td><td>2017</td><td>M01</td></tr><tr><td>330.79</td><td>2017</td><td>M01</td></tr><tr><td>331.43</td><td>2017</td><td>M01</td></tr><tr><td>332.23</td><td>2016</td><td>M ...

-- %%
-- tried to make the list only 2 values, one from each year and then grouping them by value but it wont work. 
SELECT TOP 1 ROUND(AVG(a.value),0), a.year, a.period
FROM LaborStatisticsDB.dbo.annual_2016 AS a
INNER JOIN LaborStatisticsDB.dbo.series AS s on
s.series_id = a. series_id
WHERE s.data_type_code = 30
UNION
SELECT TOP 1 ROUND(AVG(j.VALUE),0), j.YEAR, j.PERIOD
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s on
s.series_id = j.series_id
WHERE s.data_type_code = 30
GROUP BY ROUND(AVG(a.value),0);
-- Out:
-- : Msg 8120, Level 16, State 1, Line 1
-- Column 'LaborStatisticsDB.dbo.annual_2016.year' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- : Msg 4104, Level 16, State 1, Line 12
-- The multi-part identifier "a.value" could not be bound.
-- Total execution time: 00:00:00.045

-- %%
SELECT TOP 1 ROUND(AVG(a.value),0), a.year, a.period
FROM LaborStatisticsDB.dbo.annual_2016 AS a
INNER JOIN LaborStatisticsDB.dbo.series AS s on
s.series_id = a. series_id
WHERE s.data_type_code = 30
GROUP BY a.year
UNION
SELECT TOP 1 ROUND(AVG(j.VALUE),0), j.YEAR, j.PERIOD
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s on
s.series_id = j.series_id
WHERE s.data_type_code = 30
GROUP BY j.year
-- Out:
-- : Msg 8120, Level 16, State 1, Line 1
-- Column 'LaborStatisticsDB.dbo.annual_2016.period' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- Total execution time: 00:00:00.039

-- %%
-- maybe?
SELECT TOP 1(value), year, period
FROM (
    SELECT ROUND(AVG(a.value),0), a.year, a.period
    FROM LaborStatisticsDB.dbo.annual_2016 AS a
    INNER JOIN LaborStatisticsDB.dbo.series AS s ON
    s.series_id = a. series_id
    WHERE s.data_type_code = 30
    UNION ALL
    SELECT ROUND(AVG(j.VALUE),0), j.YEAR, j.PERIOD
    FROM LaborStatisticsDB.dbo.january_2017 AS j
    INNER JOIN LaborStatisticsDB.dbo.series AS s on
    s.series_id = j.series_id
    WHERE s.data_type_code = 30
)
GROUP BY year
-- Out:
-- : Msg 156, Level 15, State 1, Line 16
-- Incorrect syntax near the keyword 'GROUP'.
-- Total execution time: 00:00:00.032

-- %%
SELECT AVG(a.value) AS "avg weekly earnings 2016", a.year, a.period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a 
UNION 
SELECT AVG(j.value) AS "avg weekly earnings 2017", j.year, j.period
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
WHERE s.data_type_code = 30 
GROUP BY AVG(a.value)
-- Out:
-- : Msg 8120, Level 16, State 1, Line 1
-- Column 'LaborStatisticsDB.dbo.annual_2016.year' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- : Msg 4104, Level 16, State 1, Line 9
-- The multi-part identifier "a.value" could not be bound.
-- Total execution time: 00:00:00.037

-- %%
-- seccond try
SELECT AVG(a.value) AS "avg weekly earnings 2016", a.year, a.period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a 
UNION 
SELECT AVG(j.value) AS "avg weekly earnings 2017", j.year, j.period
FROM LaborStatisticsDB.dbo.january_2017 AS j 
JOIN LaborStatisticsDB.dbo.series AS s 
ON j.series_id = s.series_id
WHERE s.data_type_code = 30 
GROUP BY a.value
-- Out:
-- : Msg 8120, Level 16, State 1, Line 2
-- Column 'LaborStatisticsDB.dbo.annual_2016.year' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- : Msg 4104, Level 16, State 1, Line 10
-- The multi-part identifier "a.value" could not be bound.
-- Total execution time: 00:00:00.035

-- %%
SELECT AVG(a.value) AS "avg weekly earnings 2016", a.year, a.period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a
UNION 
SELECT AVG(j.value) AS "avg weekly earnings 2017", j.year, j.period
FROM LaborStatisticsDB.dbo.january_2017 AS j 
UNION 
SELECT s.series_id, s.data_type_code
FROM LaborStatisticsDB.dbo.series AS s 
WHERE s.data_type_code = 30
-- Out:
-- : Msg 156, Level 15, State 1, Line 7
-- Incorrect syntax near the keyword 'UNION'.
-- Total execution time: 00:00:00.029

-- %%
SELECT AVG(a.value) AS "avg weekly earnings 2016", a.year, a.period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a
UNION 
SELECT AVG(j.value) AS "avg weekly earnings 2017", j.year, j.period
FROM LaborStatisticsDB.dbo.january_2017 AS j 
UNION 
SELECT s.series_id, s.data_type_code
FROM LaborStatisticsDB.dbo.series AS s 
WHERE s.data_type_code = 30 
GROUP BY a.value
-- Out:
-- : Msg 8120, Level 16, State 1, Line 1
-- Column 'LaborStatisticsDB.dbo.annual_2016.year' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- : Msg 4104, Level 16, State 1, Line 10
-- The multi-part identifier "a.value" could not be bound.
-- Total execution time: 00:00:00.038

-- %%
SELECT j.value AS "avg weekly earnings 2017", j.year, j.period
FROM LaborStatisticsDB.dbo.january_2017 AS j 
UNION 
SELECT a.value AS "avg weekly earnings 2016", a.year, a.period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a
ORDER BY value
-- Out:
-- (23789 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.283
-- <table><tr><th>avg weekly earnings 2017</th><th>year</th><th>period</th></tr><tr><td>0.9</td><td>2017</td><td>M01</td></tr><tr><td>1.2</td><td>2017</td><td>M01</td></tr><tr><td>1.3</td><td>2017</td><td>M01</td></tr><tr><td>1.4</td><td>2016</td><td>M13</td></tr><tr><td>1.4</td><td>2017</td><td>M01</td></tr><tr><td>1.5</td><td>2016</td><td>M13</td></tr><tr><td>1.5</td><td>2017</td><td>M01</td></tr><tr><td>1.6</td><td>2016</td><td>M13</td></tr><tr><td>1.6</td><td>2017</td><td>M01</td></tr><tr><td>1.7</td><td>2016</td><td>M13</td></tr><tr><td>1.7</td><td>2017</td><td>M01</td></tr><tr><td>1.8</td><td>2017</td><td>M01</td></tr><tr><td>1.9</td><td>2016</td><td>M13</td></tr><tr><td>1.9</td><td>2017</td><td>M01</td></tr><tr><td>2</td><td>2016</td><td>M13</td></tr><tr><td>2</td><td>2017</td><td>M01</td></tr><tr><td>2.1</td><td>2016</td><td>M13</td></tr><tr><td>2.1</td><td>2017</td><td>M01</td></tr><tr><td>2.2</td><td>2017</td><td>M01</td></tr><tr><td>2.3</td><td>2016</td><td>M13</td></tr><tr><td>2.3</td><td>2017</td><td>M01</td></tr><tr><td>2.4</td><td>2016</td><td>M13</td></tr><tr><td>2.4</td><td>2017</td><td>M01</td></tr><tr><td>2.5</td><td>2016</td><td>M13</td></tr><tr><td>2.5</td><td>2017</td><td>M01</td></tr><tr><td>2.6</td><td>2016</td><td>M13</td></tr><tr><td>2.6</td><td>2017</td><td>M01</td></tr><tr><td>2.7</td><td>2016</td><td>M13</td></tr><tr><td>2.7</td><td>2017</td><td>M01</td></tr><tr><td>2.8</td><td>2016</td><td>M13</td></tr><tr><td>2.8</td><td>2017</td><td>M01</td></tr><tr><td>2.9</td><td>2016</td><td>M13</td></tr><tr><td>2.9</td><td>2017</td><td>M01</td></tr><tr><td>3</td><td>2016</td><td>M13</td></tr><tr><td>3</td><td>2017</td><td>M01</td></tr><tr><td>3.1</td><td>2016</td><td>M13</td></tr><tr><td>3.1</td><td>2017</td><td>M01</td></tr><tr><td>3.2</td><td>2016</td><td>M13</td></tr><tr><td>3.2</td><td>2017</td><td>M01</td></tr><tr><td>3.3</td><td>2016</td><td>M13</td></tr><tr><td>3.3</td><td>2017</td><td>M01</td></tr><tr><td>3.4</td><td>2016</td><td>M13</td></tr><tr><td>3.4</td><td>2017</td><td>M01</td></tr><tr><td>3.5</td><td>2016</td><td>M13</td></tr><tr><td>3.5</td><td>2017</td><td>M01</td></tr><tr><td>3.6</td><td>2016</td><td>M13</td></tr><tr><td>3.6</td><td>2017</td><td>M01</td></tr><tr><td>3.7</td><td>2016</td><td>M13</td></tr><tr><td>3.7</td><td>2017</td><td>M01</td></tr><tr><td>3.8</td><td>2016</td><td>M13</td></tr><tr><td>3.8</td><td>2017</td><td>M01</td></tr><tr><td>3.9</td><td>2016</td><td>M13</td></tr><tr><td>3.9</td><td>2017</td><td>M01</td></tr><tr><td>4</td><td>2016</td><td>M13</td></tr><tr><td>4</td><td>2017</td><td>M01</td></tr><tr><td>4.1</td><td>2016</td><td>M13</td></tr><tr><td>4.1</td><td>2017</td><td>M01</td></tr><tr><td>4.2</td><td>2016</td><td>M13</td></tr><tr><td>4.2</td><td>2017</td><td>M01</td></tr><tr><td>4.3</td><td>2016</td><td>M13</td></tr><tr><td>4.3</td><td>2017</td><td>M01</td></tr><tr><td>4.31</td><td>2016</td><td>M13</td></tr><tr><td>4.33</td><td>2017</td><td>M01</td></tr><tr><td>4.35</td><td>2017</td><td>M01</td></tr><tr><td>4.36</td><td>2016</td><td>M13</td></tr><tr><td>4.37</td><td>2017</td><td>M01</td></tr><tr><td>4.4</td><td>2016</td><td>M13</td></tr><tr><td>4.4</td><td>2017</td><td>M01</td></tr><tr><td>4.42</td><td>2017</td><td>M01</td></tr><tr><td>4.47</td><td>2017</td><td>M01</td></tr><tr><td>4.5</td><td>2016</td><td>M13</td></tr><tr><td>4.5</td><td>2017</td><td>M01</td></tr><tr><td>4.53</td><td>2017</td><td>M01</td></tr><tr><td>4.6</td><td>2016</td><td>M13</td></tr><tr><td>4.6</td><td>2017</td><td>M01</td></tr><tr><td>4.61</td><td>2017</td><td>M01</td></tr><tr><td>4.62</td><td>2016</td><td>M13</td></tr><tr><td>4.65</td><td>2017</td><td>M01</td></tr><tr><td>4.7</td><td>2016</td><td>M13</td></tr><tr><td>4.7</td><td>2017</td><td>M01</td></tr><tr><td>4.71</td><td>2017</td><td>M01</td></tr><tr><td>4.74</td><td>2016</td><td>M13</td></tr><tr><td>4.75</td><td>2017</td><td>M01</td></tr><tr><td>4.79</td><td>2016</td><td>M13</td></tr><tr><td>4.79</td><td>2017</td><td>M01</td></tr><tr><td>4 ...

-- %%
SELECT j.value AS "avg weekly earnings 2017", j.year, j.period
FROM LaborStatisticsDB.dbo.january_2017 AS j 
UNION 
SELECT a.value AS "avg weekly earnings 2016", a.year, a.period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a
GROUP BY year
ORDER BY value
-- Out:
-- : Msg 8120, Level 16, State 1, Line 4
-- Column 'LaborStatisticsDB.dbo.annual_2016.value' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- Total execution time: 00:00:00.032

-- %%
SELECT a.value 
from LaborStatisticsDB.dbo.annual_2016 AS a
   where a.value in
      (select stor_id from
         (select a.value from sales
          union
          select j.value from aborStatisticsDB.dbo.january_2017 AS j)
       dt_stores)

-- %% [markdown]
-- ## <span style="font-size:12pt;font-family:Montserrat, sans-serif;color:rgb(53, 74, 95);background-color:rgb(255, 255, 255);font-weight:700;vertical-align:baseline;white-space:pre-wrap;">Summarize Your Results</span>
--
-- <span style="font-size:10pt;font-family:Arvo, serif;color:rgb(102, 102, 102);background-color:rgb(255, 255, 255);vertical-align:baseline;white-space:pre-wrap;">With what you know now about the </span> <span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:&quot;Times New Roman&quot;;font-size:13.3333px;white-space:pre-wrap;">Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results and working with the</span> <span style="color:rgb(102, 102, 102);white-space:pre-wrap;font-family:&quot;Times New Roman&quot;;font-size:13.3333px;">Labor Statistics Database</span><span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:Arvo, serif;font-size:10pt;white-space:pre-wrap;">, answer the following questions. Note that while this is subjective, you should include relevant data to back up your opinion.</span>
--
-- 1. <span style="background-color:rgb(255, 255, 255);font-size:10pt;white-space:pre-wrap;color:rgb(102, 102, 102);font-family:Arvo, serif;">During which time period did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- The production and nonsupervisory employees did better in ....I cannot get the last question to work.

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In which industries did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- Highest paid employees worked for the private sector and the lowest paid employees worked at bowling centers.

-- %% [markdown]
-- 3. <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Now that you have explored the datasets, is there any data or information that you wish you had in this analysis?</span>

-- %% [markdown]
-- A better list of what certain series\_id titles were.  It was frusterating to always have to look up what the code might be for a certain group of employees.
